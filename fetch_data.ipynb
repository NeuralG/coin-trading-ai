# %%
stocks = [
    "THYAO.IS",
    "KCHOL.IS",
    "ASELS.IS",
    "EREGL.IS",
    "SISE.IS",
    "SAHOL.IS",
    "TUPRS.IS",
    "AKBNK.IS",
    "YKBNK.IS",
    "ISCTR.IS",
    "BIMAS.IS",
    "PETKM.IS",
    "KRDMD.IS",
    "TCELL.IS",
    "EKGYO.IS",
    "ODAS.IS",
    "HEKTS.IS",
    "SASA.IS",
    "ENKAI.IS",
    "GARAN.IS",
    "FROTO.IS",
    "TOASO.IS",
    "ARCLK.IS",
    "ASTOR.IS",
    "KOZAL.IS",
    "KOZAA.IS",
    "MGROS.IS",
    "PGSUS.IS",
    "TTKOM.IS",
    "VESTL.IS",
]
